# %%
import folium
import numpy as np
import pandas as pd 
from scipy.signal import medfilt
import matplotlib.pyplot as plt

from service import  load_racimo_data
from service import load_amb_data
from service import linear_calibration_model
from service import random_forest_calibration

# %% [markdown]
# ### Distribución Geografica de las estaciones
# Se muestra la distribución geográfica de las estaciones disponibles para el estudio. Las estaciones pertenecientes al AMB se muestran en color <span style="color:red">rojo</span>, mientras que las que pertenecen a RACIMO se muestran en color <span style="color:blue">azul</span>.

# %%
# Ubicación de las estaciones
racimodict={"comuneros":[7.13605040,-73.1287364],"ecologico":[7.03922040,-73.1194441],"galan":[7.09200830,-73.0919307],
         "isidrocaballero":[7.08807850,-73.0994883],"itsdz":[7.13863530,-73.11866490000001],"mutis":[7.1059880,-73.1236424],
         "normal":[7.126296,-73.1195564],"santander":[7.13936450,-73.1224860999]}
ambdict={"amb_acualago":[7.071854,-73.101586],"amb_caldas":[7.099963,-73.104161],"amb_giron":[7.060667,-73.172077],
            "amb_normal":[7.1270292,-73.1182707],"amb_pilar":[7.106642,-73.123992]}

#Se crea un dataFrame a partir del diccionario y luego se traspone
ambloc=pd.DataFrame(ambdict).T
racimoloc=pd.DataFrame(racimodict).T
ambnames=["amb_acualago","amb_caldas","amb_giron","amb_normal","amb_pilar"]
racimonames=["comuneros","ecologico","galan","isidrocaballero","itsdz","mutis","normal","santander"]

map = folium.Map(location=[np.mean(ambloc[0]),np.mean(ambloc[1])], zoom_start=13)
for point in range(0, len(ambloc)):
    folium.Marker([ambloc[0][point],ambloc[1][point]], popup=folium.Popup(ambnames[point],show=False), icon=folium.Icon(color='blue',prefix='fa',icon='pagelines')).add_to(map)
for point in range(0, len(racimoloc)):
    folium.Marker([racimoloc[0][point],racimoloc[1][point]], popup=folium.Popup(racimonames[point],show=False), icon=folium.Icon(color='red',prefix='fa',icon='pagelines',angle='90')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d699d284ca8cf20d0931f6eb1dcdedec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d699d284ca8cf20d0931f6eb1dcdedec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d699d284ca8cf20d0931f6eb1dcdedec = L.map(
#                 &quot;map_d699d284ca8cf20d0931f6eb1dcdedec&quot;,
#                 {
#                     center: [7.093231039999999, -73.12401734],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a21fa3bd33f2810c8b14f858a36c9636 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d699d284ca8cf20d0931f6eb1dcdedec);
#
#
#             var marker_bd31fabe13afb0fe617aa65ced96e855 = L.marker(
#                 [7.071854, -73.101586],
#                 {}
#             ).addTo(map_d699d284ca8cf20d0931f6eb1dcdedec);
#
#
#             var icon_708a6b13d92739e7b2eec107159a373d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;pagelines&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bd31fabe13afb0fe617aa65ced96e855.setIcon(icon_708a6b13d92739e7b2eec107159a373d);
#
#
#         var popup_7f6c6206c199a594bd78228d1b7b3f8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f235f554954211158f667b9280b74168 = $(`&lt;div id=&quot;html_f235f554954211158f667b9280b74168&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;amb_acualago&lt;/div&gt;`)[0];
#                 popup_7f6c6206c199a594bd78228d1b7b3f8a.setContent(html_f235f554954211158f667b9280b74168);
#
#
#
#         marker_bd31fabe13afb0fe617aa65ced96e855.bindPopup(popup_7f6c6206c199a594bd78228d1b7b3f8a)
#         ;
#
#
#
#
#             var marker_be5c7ee2d475910e16741e310106a17b = L.marker(
#                 [7.099963, -73.104161],
#                 {}
#             ).addTo(map_d699d284ca8cf20d0931f6eb1dcdedec);
#
#
#             var icon_f23adc190d0b30ba600931c2f1c1d8d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;pagelines&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_be5c7ee2d475910e16741e310106a17b.setIcon(icon_f23adc190d0b30ba600931c2f1c1d8d7);
#
#
#         var popup_c518cb13a26fab73e565ed4200f6249e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8387fcd17497a2796ac64795ffbb1861 = $(`&lt;div id=&quot;html_8387fcd17497a2796ac64795ffbb1861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;amb_caldas&lt;/div&gt;`)[0];
#                 popup_c518cb13a26fab73e565ed4200f6249e.setContent(html_8387fcd17497a2796ac64795ffbb1861);
#
#
#
#         marker_be5c7ee2d475910e16741e310106a17b.bindPopup(popup_c518cb13a26fab73e565ed4200f6249e)
#         ;
#
#
#
#
#             var marker_0c559e21d21011eaf2285c575749c61e = L.marker(
#                 [7.060667, -73.172077],
#                 {}
#             ).addTo(map_d699d284ca8cf20d0931f6eb1dcdedec);
#
#
#             var icon_5c2f3c0ca080b327e0e6feb1e5e6957f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;pagelines&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0c559e21d21011eaf2285c575749c61e.setIcon(icon_5c2f3c0ca080b327e0e6feb1e5e6957f);
#
#
#         var popup_1686eb585907300066b6659d19b81f8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ed5341714110e2a233701b6c2a2db81 = $(`&lt;div id=&quot;html_9ed5341714110e2a233701b6c2a2db81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;amb_giron&lt;/div&gt;`)[0];
#                 popup_1686eb585907300066b6659d19b81f8c.setContent(html_9ed5341714110e2a233701b6c2a2db81);
#
#
#
#         marker_0c559e21d21011eaf2285c575749c61e.bindPopup(popup_1686eb585907300066b6659d19b81f8c)
#         ;
#
#
#
#
#             var marker_1149648f33cd0863c22b74f3e9e2932b = L.marker(
#                 [7.1270292, -73.1182707],
#                 {}
#             ).addTo(map_d699d284ca8cf20d0931f6eb1dcdedec);
#
#
#             var icon_d844312d1bc16de08b01c549992c3b90 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;pagelines&quot;, &

# %% [markdown]
# En el mapa anterior se puede ver con claridad, que solo un par de estaciones son adecuadas para este análisis. Estas serian las de la **normal** y **mutis**. El resto de estaciones de los sensores bajo costo se encuentra lejos de las de referencia.

# %% [markdown]
# ### Visualización exploratoria de los datos las estaciones de la **normal** y **mutis** de RACIMO

# %%
# Cargar los datos de racimo
normal=load_racimo_data("Data/normal.csv")
mutis=load_racimo_data("Data/mutis.csv")

# %%
plt.figure(figsize = (30,6))
plt.subplots_adjust(left = 0.125,right = 0.9,bottom = 0.0,top = 0.92,wspace = 0.05,hspace = 0.2)
plt.suptitle("PM10 para las estaciones RACIMO",fontweight='bold',fontsize=14)
plt.subplot(1,2,1)
normal.pm10_a.plot(label = 'Normal')
plt.legend(fontsize = 14)
plt.subplot(1,2,2)
mutis.pm10_a.plot(label = 'Mutis')
plt.legend(fontsize = 14)

plt.show()

# %%
plt.figure(figsize = (30,6))
plt.subplots_adjust(left = 0.125,right = 0.9,bottom = 0.0,top = 0.92,wspace = 0.05,hspace = 0.2)
plt.suptitle("PM2.5 para las estaciones RACIMO",fontweight='bold',fontsize=14)
plt.subplot(1,2,1)
normal.pm25_a.plot(label = 'Normal')
plt.legend(fontsize = 14)
plt.subplot(1,2,2)
mutis.pm25_a.plot(label = 'Mutis')
plt.legend(fontsize = 14)

# %% [markdown]
# De las gráficas anteriores se puede concluir que la estación **mutis** no es apropiada para realizar el análisis, por la poda disponibilidad de datos, por tanto el estudio se realizara utilizando los datos la estación **normal**

# %% [markdown]
# La data de la AMB contiene las siguientes variables:
# - PM10 [$\mu g/m^3$]: material particulado
# - PM2.5 [$\mu g/m^3$]:
# - Temp_Aire [°C]: temperatura del aire
# - Lluvia [mm]:
# - Humedad_relativa [%]:
# - WD [Grados]: Dirección del viento
# - WS [m/s]: Velocidad del viento
# - R_solar [$W/m^2$]: Radiación solar

# %%
# Cargar datos del AMB
normal_amb = load_amb_data("Data/amb_normal.xls")
normal_amb = normal_amb.dropna()

# %% [markdown]
# ### Análisis de componentes principales

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Carga tus datos (reemplaza 'data.csv' con el nombre de tu archivo)
data = normal_amb

# Estandariza las variables
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Aplica PCA
pca = PCA()
pca.fit(scaled_data)
# Out:
# PCA()

# %%
# Visualiza la varianza explicada en función de las componentes empleadas
plt.figure(figsize=(7,6))
num_components = np.arange(1, len(pca.explained_variance_ratio_) + 1)
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# Crea un gráfico de barras
bar_plot = plt.bar(num_components, cumulative_variance, color = 'blue')
plt.plot(np.arange(1, len(pca.explained_variance_ratio_) + 1), np.cumsum(pca.explained_variance_ratio_))


# Agrega etiquetas sobre cada barra
for bar in bar_plot:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:.2f}', ha='center', va='bottom')

plt.xlabel('Number of components', fontsize = 16)
plt.ylabel('Cumulative explained variance', fontsize = 16)
plt.title('Explained variance as a function of the employed components', fontsize = 16)
#plt.savefig("pca_bar.pdf",bbox_inches='tight',pad_inches=0)
plt.show()

# %%
data.columns
# Out:
# Index(['PM10', 'PM2.5', 'Temp_Aire', 'Lluvia', 'Humedad_relativa', 'WD', 'WS',
#        'R_Solar'],
#       dtype='object')

# %%
# Visualiza la contribución de cada variable a las dos dimensiones que explican la mayor varianza
loadings = pca.components_[:2].T
plt.figure(figsize=(7,6))
plt.scatter(loadings[:, 0], loadings[:, 1])

# Agrega un vector desde el origen hasta cada punto del scatter
for loading in loadings:
    plt.arrow(0, 0, loading[0], loading[1], color='blue', lw=0.5)

# Mejora la ubicación del texto asociado a cada punto
offset = 0.005
for i, txt in enumerate(['PM10','PM2.5','Temp_Aire','Precipitación','Hr','WD','WS','R_Solar']):
    if txt == 'PM10':
        plt.annotate(txt, (loadings[i, 0] - 0.13, loadings[i, 1] - 0.05), fontsize =16)
    elif txt == 'Precipitación':
        plt.annotate(txt, (loadings[i, 0] + offset, loadings[i, 1]- 0.03), fontsize =16)

    else:
        plt.annotate(txt, (loadings[i, 0] + offset, loadings[i, 1] + offset), fontsize =16)
    
plt.xlabel('Principal component 1', fontsize = 16)
plt.ylabel('Principal component 2',  fontsize = 16)
plt.title('Variable Impact on Major PCA Dimension', fontsize = 16)
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.ylim(-0.4,0.7)
plt.xlim(-0.6,0.6)
plt.grid()
#plt.savefig("pca_componets.png",bbox_inches='tight',pad_inches=0, dpi= 300)
plt.show()

# %%
plt.figure(figsize = (18,6))
normal.pm10_a.plot()
normal_amb.PM10.plot()
plt.show()

# %%
# Suavisar los datos usando un filtro de mediana a las columnas de particulado
for column in normal_amb.columns:
    normal_amb[column] = medfilt(normal_amb[column],21)

for column in normal.columns:
    normal[column] = medfilt(normal[column],21)

# Unir las dos datas en una sola y dejar solo donde hay datos en las dos
data = pd.concat([normal_amb,normal],axis = 1).dropna()

# %%
import numpy as np

def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse_value = rmse(data.PM10, data.pm10_a)
rmse_value
# Out:
# 12.293834843726922

# %%
rmseRF = 1.6833
rmseLR = 3.6541
rmseMLR = 3.2393 

((rmseLR -rmseRF)/rmseLR) * 100
# Out:
# 53.93393722120358

# %%
((rmse_value -rmseRF)/rmse_value) * 100
# Out:
# 86.30777116011994

# %%
((rmse_value -rmseLR)/rmse_value) * 100
# Out:
# 70.27697177935859

# %%
((rmse_value -rmseMLR)/rmse_value) * 100
# Out:
# 73.65102068495013

# %%
plt.figure(figsize = (8,5))
data.pm10_a.plot(label='PM$_{10}$ low-cost',lw=1,c='b')
data.PM10.plot(label='PM$_{10}$ reference',lw=1,c='k')
plt.legend(fontsize = 16)
plt.ylabel("PM$_{10}$ (ppb)", fontsize =16)
plt.grid(axis='y')
plt.ylim(0,50)
plt.xticks(pd.date_range(start=data.index.min(), end=data.index.max(), freq='3W'),rotation=0)
# ax = plt.gca()
# ax.xaxis.set_major_locator(mdates.AutoDateLocator())
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

#plt.savefig("pm10_normal_var.pdf",bbox_inches='tight',pad_inches=0)
plt.show()

# %%
plt.figure(figsize=(8,5))
data.pm25_a.plot(label='PM$_{2.5}$ low-cost',lw=1,c='b')
data["PM2.5"].plot(label='PM$_{2.5}$ reference',lw=1,c='k')
plt.legend(fontsize =16)
plt.ylabel("PM$_{2.5}$ (ppb)", fontsize = 12)
plt.grid(axis='y')
plt.ylim(0,40)
plt.xticks(pd.date_range(start=data.index.min(), end=data.index.max(), freq='3W'),rotation=0)
#plt.savefig("pm25_normal_var.pdf",bbox_inches='tight',pad_inches=0)
plt.show()

# %% [markdown]
# ### Linear calibration model

# %%
# PM10
LR_pm10 = linear_calibration_model(data['pm10_a'],data['PM10'])
# PM2.5
LR_pm25 = linear_calibration_model(data['pm25_a'],data['PM2.5'])

# %%
print('Linear model - PM10')
LR_pm10
# Out:
# Linear model - PM10
# {'RMSE': 3.7808183135159394,
#  'COEF': array([0.70568475]),
#  'Intercept': 15.65143716359315,
#  'r2_score': 0.5624833245924733,
#  'correlation': 0.8374150558658946,
#  'NRMSE': 0.062345520498954414}

# %%
print('Linear model - PM25')
LR_pm25
# Out:
# Linear model - PM25
# {'RMSE': 1.559455796632976,
#  'COEF': array([0.56005665]),
#  'Intercept': 4.67974309960526,
#  'r2_score': 0.8551068685279937,
#  'correlation': 0.9340712745061993,
#  'NRMSE': 0.048451841624412725}

# %% [markdown]
# ### Multilinear calibration model

# %%
data.columns
# Out:
# Index(['PM10', 'PM2.5', 'Temp_Aire', 'Lluvia', 'Humedad_relativa', 'WD', 'WS',
#        'R_Solar', 'pm10', 'pm10_a', 'pm25', 'pm25_a', 't', 'p', 'h'],
#       dtype='object')

# %%
MLR_pm10 = linear_calibration_model(data[['pm10_a','t','p','h', 'R_Solar']],data['PM10'])
MLR_pm25 = linear_calibration_model(data[['pm25_a','t','p','h','R_Solar']],data['PM2.5'])

# %%
print('Multilinear model - PM10')
MLR_pm10
# Out:
# Multilinear model - PM10
# {'RMSE': 3.367400820192111,
#  'COEF': array([ 0.7537285 , -0.99318147, -0.49526771, -0.66718435,  0.00164203]),
#  'Intercept': 526.329438507765,
#  'r2_score': 0.7193946904213447,
#  'correlation': 0.8824647774952153,
#  'NRMSE': 0.05753336041265268}

# %%
print('Multilinear model - PM2.5')
MLR_pm25
# Out:
# Multilinear model - PM2.5
# {'RMSE': 1.3267507519197475,
#  'COEF': array([ 0.58205983, -0.44026118, -0.52083408, -0.24818352,  0.00074897]),
#  'Intercept': 500.29634241171874,
#  'r2_score': 0.9062864068826106,
#  'correlation': 0.955424185995284,
#  'NRMSE': 0.04584208416684263}

# %% [markdown]
# ### Ramdom forest

# %%
# PM10
pm10_rf, RF_pm10 = random_forest_calibration( data[['pm10_a','t','p','h','R_Solar']], data['PM10'])
# PM2.5
pm25_rf, RF_pm25 = random_forest_calibration( data[['pm25_a','t','p','h','R_Solar']], data['PM2.5'])
# Out:
# mse [0.79924264 0.0361504  0.04138079 0.10206732 0.02115885] <bound method BaseEstimator.get_params of RandomForestRegressor(n_estimators=800, random_state=429)> 5
# mse [0.90162518 0.02749969 0.02303701 0.03671198 0.01112614] <bound method BaseEstimator.get_params of RandomForestRegressor(n_estimators=800, random_state=332)> 5

# %%
print('RF - PM10')
RF_pm10
# Out:
# RF - PM10
# {'RMSE': 1.7447164890805231,
#  'r2_score': 0.9350384819190529,
#  'correlation': 0.9690431258817256,
#  'NRMSE': 0.028207176980825865,
#  'accuracy': 95.4572638338107}

# %%
print('RF - PM2.5')
RF_pm25
# Out:
# RF - PM2.5
# {'RMSE': 0.9552717968281633,
#  'r2_score': 0.9530523583232021,
#  'correlation': 0.9771272264027371,
#  'NRMSE': 0.029591938413636165,
#  'accuracy': 95.50284405849948}

# %%
LR_pm10.keys()
# Out:
# dict_keys(['RMSE', 'COEF', 'Intercept', 'r2_score', 'correlation', 'NRMSE'])

# %%
plt.figure(figsize=(7,6))

plt.scatter(data["PM10"],data["pm10_a"]*LR_pm10['COEF'][0] + LR_pm10['Intercept'], label='Linear Regression',lw=0.01,marker='s',alpha=1,c='r',s=10)
plt.scatter(data["PM10"],data["pm10_a"]*MLR_pm10['COEF'][0]+
            data["t"]*MLR_pm10['COEF'][1]+
            data["p"]*MLR_pm10['COEF'][2]+
            data["h"]*MLR_pm10['COEF'][3]+
            MLR_pm10['Intercept'],label='Multivariate Linear Regression',lw=0.01,marker=7,alpha=1,c='b',s=25)
plt.scatter(pm10_rf,data["PM10"],label='Random Forest',lw=0.01,marker='o',alpha=1,c='g',s=10) 
x=np.linspace(15,100,10)
plt.plot(x,x,'k-')
plt.ylabel("PM$_{10}$ reference", fontsize = 16)
plt.xlabel("PM$_{10}$ low-cost", fontsize = 16)
plt.ylim(15,50)
plt.xlim(15,50)
plt.grid()
plt.legend(fontsize = 12)
#plt.savefig("pm10_normal_method.png",bbox_inches='tight',pad_inches=0, dpi=300)


plt.show()

# %%
data.columns
# Out:
# Index(['PM10', 'PM2.5', 'Temp_Aire', 'Lluvia', 'Humedad_relativa', 'WD', 'WS',
#        'R_Solar', 'pm10', 'pm10_a', 'pm25', 'pm25_a', 't', 'p', 'h'],
#       dtype='object')

# %%
plt.figure(figsize=(7,6))

plt.scatter(data["PM2.5"],data["pm25_a"]*LR_pm25['COEF'][0] + LR_pm25['Intercept'], label='Linear Regression',lw=0.01,marker='s',alpha=1,c='r',s=10)
plt.scatter(data["PM2.5"],data["pm25_a"]*MLR_pm25['COEF'][0]+
            data["t"]*MLR_pm25['COEF'][1]+
            data["p"]*MLR_pm25['COEF'][2]+
            data["h"]*MLR_pm25['COEF'][3]+
            MLR_pm25['Intercept'],label='Multivariate Linear Regression',lw=0.01,marker=7,alpha=1,c='b',s=25)
plt.scatter(pm25_rf,data["PM2.5"],label='Random Forest',lw=0.01,marker='o',alpha=1,c='g',s=10) 
x=np.linspace(5,100,10)
plt.plot(x,x,'k-')
plt.ylabel("PM$_{2.5}$ reference", fontsize = 16)
plt.xlabel("PM$_{2.5}$ low-cost", fontsize = 16)
plt.ylim(5,30)
plt.xlim(5,30)
plt.grid()
plt.legend(fontsize = 12)
#plt.savefig("pm25_normal_method.png",bbox_inches='tight',pad_inches=0, dpi=300)


plt.show()

# %%
import matplotlib.patches as patches

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18,5))

# subplot 1
data["pm10_a"].plot(label="before calibration (low-cost)", lw=1, c='b', ax=ax1)

ax1.plot(data.index,data["pm10_a"]*LR_pm10['COEF'][0] + LR_pm10['Intercept'],
         label='after linear calibration',lw=1,c='r',linestyle='-',alpha=0.7)
ax1.plot(data.index,data["pm10_a"]*MLR_pm10['COEF'][0]+
            data["t"]*MLR_pm10['COEF'][1]+
            data["p"]*MLR_pm10['COEF'][2]+
            data["h"]*MLR_pm10['COEF'][3]+
            MLR_pm10['Intercept'],label='after linear multiple calibration',lw=1,c='g',linestyle='-',alpha=0.7)
ax1.plot(data.index,pm10_rf,label='after Random Forest calibration',lw=1,c='orange',linestyle='-',alpha=0.7)
data["PM10"].plot(label="reference", lw=1, c='k', linestyle='--', ax=ax1)
ax1.plot([data.index[1424] , data.index[1591] ], [5, 5], color='r',linewidth=2)
ax1.plot([data.index[1424] ,  data.index[1424]], [5, 35], color='r', linewidth=2)
ax1.plot([data.index[1424] , data.index[1591] ], [35, 35], color='r',linewidth=2)
ax1.plot([data.index[1591] ,data.index[1591] ], [35, 5], color='r', linewidth=2)

ax1.set_ylim(0, 50)
ax1.legend(ncol=2)
ax1.set_ylabel("PM$_{10}$ (ppb)", fontsize = 16)
ax1.grid(axis='y')
ax1.set_xticks(pd.date_range(start=data.index.min(), end=data.index.max(), freq='3W'))
ax1.tick_params(axis='x', rotation=0)

# subplot 2
data["pm10_a"].plot(label="before calibration (low-cost)", lw=3, c='b', ax=ax2)

ax2.plot(data.index,data["pm10_a"]*LR_pm10['COEF'][0] + LR_pm10['Intercept'],
         label='after linear calibration',lw=3,c='r',alpha=0.7)
ax2.plot(data.index,data["pm10_a"]*MLR_pm10['COEF'][0]+
            data["t"]*MLR_pm10['COEF'][1]+
            data["p"]*MLR_pm10['COEF'][2]+
            data["h"]*MLR_pm10['COEF'][3]+
            MLR_pm10['Intercept'],label='after linear multiple calibration',lw=3,c='g',linestyle='-',alpha=0.7)
ax2.plot(data.index,pm10_rf,label='after Random Forest calibration',lw=3,c='orange',linestyle='-',alpha=0.7)
data["PM10"].plot(label="reference", lw=3, c='k', linestyle='-', ax=ax2)
ax2.set_ylim(5, 35)
ax2.set_xlim('2019-06-16', '2019-06-23')
ax2.legend(ncol=2)
ax2.set_ylabel("PM$_{10}$ (ppb)",  fontsize = 16)
ax2.grid(axis='y')
#plt.savefig("pm10_normal_allcalib.png",bbox_inches='tight',pad_inches=0, dpi = 300)

# %%
import matplotlib.patches as patches

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18,5))

# subplot 1
data["pm25_a"].plot(label="before calibration (low-cost)", lw=1, c='b', ax=ax1)

ax1.plot(data.index,data["pm25_a"]*LR_pm25['COEF'][0] + LR_pm25['Intercept'],
         label='after linear calibration',lw=1,c='r',linestyle='-',alpha=0.7)
ax1.plot(data.index,data["pm25_a"]*MLR_pm25['COEF'][0]+
            data["t"]*MLR_pm25['COEF'][1]+
            data["p"]*MLR_pm25['COEF'][2]+
            data["h"]*MLR_pm25['COEF'][3]+
            MLR_pm25['Intercept'],label='after linear multiple calibration',lw=1,c='g',linestyle='-',alpha=0.7)
ax1.plot(data.index,pm25_rf,label='after Random Forest calibration',lw=1,c='orange',linestyle='-',alpha=0.7)
data["PM2.5"].plot(label="reference", lw=1, c='k', linestyle='--', ax=ax1)
ax1.plot([data.index[1424] , data.index[1591] ], [5, 5], color='r',linewidth=2)
ax1.plot([data.index[1424] ,  data.index[1424]], [5, 35], color='r', linewidth=2)
ax1.plot([data.index[1424] , data.index[1591] ], [35, 35], color='r',linewidth=2)
ax1.plot([data.index[1591] ,data.index[1591] ], [35, 5], color='r', linewidth=2)

ax1.set_ylim(0, 50)
ax1.legend(ncol=2)
ax1.set_ylabel("PM$_{2.5}$ (ppb)", fontsize = 16)
ax1.grid(axis='y')
ax1.set_xticks(pd.date_range(start=data.index.min(), end=data.index.max(), freq='3W'))
ax1.tick_params(axis='x', rotation=0)

# subplot 2
data["pm25_a"].plot(label="before calibration (low-cost)", lw=3, c='b', ax=ax2)

ax2.plot(data.index,data["pm25_a"]*LR_pm25['COEF'][0] + LR_pm25['Intercept'],
         label='after linear calibration',lw=3,c='r',alpha=0.7)
ax2.plot(data.index,data["pm25_a"]*MLR_pm25['COEF'][0]+
            data["t"]*MLR_pm25['COEF'][1]+
            data["p"]*MLR_pm25['COEF'][2]+
            data["h"]*MLR_pm25['COEF'][3]+
            MLR_pm25['Intercept'],label='after linear multiple calibration',lw=3,c='g',linestyle='-',alpha=0.7)
ax2.plot(data.index,pm25_rf,label='after Random Forest calibration',lw=3,c='orange',linestyle='-',alpha=0.7)
data["PM2.5"].plot(label="reference", lw=3, c='k', linestyle='-', ax=ax2)
ax2.set_ylim(0, 30)
ax2.set_xlim('2019-06-16', '2019-06-23')
ax2.legend(ncol=2)
ax2.set_ylabel("PM$_{2.5}$ (ppb)",  fontsize = 16)
ax2.grid(axis='y')
#plt.savefig("pm25_normal_allcalib.png",bbox_inches='tight',pad_inches=0, dpi = 300)
